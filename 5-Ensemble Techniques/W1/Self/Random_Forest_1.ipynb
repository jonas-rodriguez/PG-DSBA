# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('heart_v2.csv')
print(df.head())
sns.countplot(df['heart disease'])
plt.title('Value counts of heart disease patients')
plt.show()
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   37    0  120         215              0
# 1   66    1  160         246              1
# 2   58    1  128         259              1
# 3   43    1  110         211              0
# 4   64    0  180         325              0
# C:\Users\jflor\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.head(10)
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   37    0  120         215              0
# 1   66    1  160         246              1
# 2   58    1  128         259              1
# 3   43    1  110         211              0
# 4   64    0  180         325              0
# 5   50    0  110         254              0
# 6   53    1  130         197              0
# 7   45    0  138         236              0
# 8   65    1  138         282              1
# 9   69    1  160         234              0

# %% [markdown]
# 3. Colocar Variable de función en X y Variable de destino en y.

# %%
# Putting feature variable to X
X = df.drop('heart disease',axis=1)
# Putting response variable to y
y = df['heart disease']

# %% [markdown]
# 4. Se realiza Train-Test-Split

# %%
# now lets split the data into train and test
from sklearn.model_selection import train_test_split
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((76, 4), (33, 4))
